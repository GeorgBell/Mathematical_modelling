# %% [markdown]
# # Эффективная ширина спектра

# %% [markdown]
# ## Импорт библиотек и считывание сигнала

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig
from math import log

# %%
dataset = pd.read_csv('Train_63.csv')
signal = dataset['Ch1, mV'].values
print(len(signal))
# Out:
# 6816

# %% [markdown]
# ## Построим сигнал

# %%
plt.plot(signal[:])
plt.title('Исходный сигнал')
plt.show()
